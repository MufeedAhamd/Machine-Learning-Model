# %%
# import important libaries
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder , OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression,LinearRegression

# %%
# read data from local disk
df = pd.read_csv(r"C:\Users\Lenovo\Downloads\archive (41).zip")
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
# rename the column name 
df["Discount_Applied"] = df ["Discount Applied"]

# %%
df = df[['Gender', 'Age', 'City', 'Membership Type',
       'Total Spend', 'Items Purchased', 'Average Rating', 'Discount_Applied',
       'Days Since Last Purchase', 'Satisfaction Level']]

# %%
# Classify data into Numerical or Categorical
cat = X.select_dtypes(include= ["object"]).columns
num = X.select_dtypes(exclude= ["object"]).columns

# %%
# Split target and feature columns
X = df.drop(columns=['Discount_Applied'], axis=1)
y = df['Discount_Applied']

# %%
from sklearn.compose import ColumnTransformer
pre = ColumnTransformer(
    transformers=[
        ("cat",OneHotEncoder(), cat),
        ("num", StandardScaler(),num)
    ]
)
pre
# Out:
# ColumnTransformer(transformers=[('cat', OneHotEncoder(),
#                                  Index(['Gender', 'City', 'Membership Type', 'Satisfaction Level'], dtype='object')),
#                                 ('num', StandardScaler(),
#                                  Index(['Age', 'Total Spend', 'Items Purchased', 'Average Rating',
#        'Days Since Last Purchase'],
#       dtype='object'))])

# %%
# make pipeline for model and make a model
from sklearn.pipeline import Pipeline

model= Pipeline(steps=[
    ("Preprocesser", pre),
    ("Logistic", LogisticRegression())
])
model
# Out:
# Pipeline(steps=[('Preprocesser',
#                  ColumnTransformer(transformers=[('cat', OneHotEncoder(),
#                                                   Index(['Gender', 'City', 'Membership Type', 'Satisfaction Level'], dtype='object')),
#                                                  ('num', StandardScaler(),
#                                                   Index(['Age', 'Total Spend', 'Items Purchased', 'Average Rating',
#        'Days Since Last Purchase'],
#       dtype='object'))])),
#                 ('Logistic', LogisticRegression())])

# %%
# Split into Training and Testing
X_train,X_test, y_train , y_test= train_test_split(X,y, test_size=.2, random_state=40)

# %%
# Fiting a  model into train data 
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('Preprocesser',
#                  ColumnTransformer(transformers=[('cat', OneHotEncoder(),
#                                                   Index(['Gender', 'City', 'Membership Type', 'Satisfaction Level'], dtype='object')),
#                                                  ('num', StandardScaler(),
#                                                   Index(['Age', 'Total Spend', 'Items Purchased', 'Average Rating',
#        'Days Since Last Purchase'],
#       dtype='object'))])),
#                 ('Logistic', LogisticRegression())])

# %%
y_pred = model.predict(X_test)

# %%
# check accuarcy of model
from sklearn.metrics import accuracy_score , confusion_matrix
acc = accuracy_score(y_pred , y_test)
con  = confusion_matrix(y_pred , y_test)

print("Model accuarcy :",acc)
print("Confusion metrics :",con)
# Out:
# Model accuarcy : 1.0
# Confusion metrics : [[36  0]
#  [ 0 34]]

# %%
df.head()
# Out:
#    Gender  Age           City Membership Type  Total Spend  Items Purchased  \
# 0  Female   29       New York            Gold      1120.20               14
# 1    Male   34    Los Angeles          Silver       780.50               11
# 2  Female   43        Chicago          Bronze       510.75                9
# 3    Male   30  San Francisco            Gold      1480.30               19
# 4    Male   27          Miami          Silver       720.40               13
#
#    Average Rating  Discount_Applied  Days Since Last Purchase  \
# 0             4.6              True                        25
# 1             4.1             False                        18
# 2             3.4              True                        42
# 3             4.7             False                        12
# 4             4.0              True                        55
#
#   Satisfaction Level
# 0          Satisfied
# 1            Neutral
# 2        Unsatisfied
# 3          Satisfied
# 4        Unsatisfied

# %%
# take live input for model test
live = pd.DataFrame({
    'Gender' :["Male"], 
    'Age' : [30], 
    'City' : ["San Francisco"], 
    'Membership Type' : ["Gold"], 
    'Total Spend' : [1480.20],
    'Items Purchased' : [19], 
    'Average Rating' : [4.7],
    'Days Since Last Purchase' : [12], 
    'Satisfaction Level' : ["Satisfied"]
})

# %%
# Use [0][1] to get the probability of the positive class for the first sample
prob = model.predict_proba(live)
positive_prob = prob[0][1] 

result = 'Discount_Applied' if positive_prob > 0.50 else "not"

print("prediction :", result)
print("positive Probability :", positive_prob)
# Out:
# prediction : not
# positive Probability : 0.027376946131169956
