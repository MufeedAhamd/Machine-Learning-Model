# %% [markdown]
# **Social Media Advertisement: Customer Purchase Prediction Model**

# %%
# import important libaries

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler , OneHotEncoder , LabelEncoder
from sklearn.model_selection import train_test_split

# %%
# read data from local disk
df = pd.read_csv(r"C:\Users\Lenovo\Downloads\Social_Network_Ads.csv")

# Checking the null value
df.isnull().sum()  

df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
# Split traget and feature columns
X = df.drop(["User ID", "Purchased"], axis = 1)
y= df["Purchased"]

# %%
# Classify data into Numerical or Categorical
cat = ["Gender"] # for Categorical data
num = ["Age","EstimatedSalary"] # for Numerical data

# %%
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        # Binary + Nominal → OneHotEncoding
        ('cat', OneHotEncoder(drop='first'), cat ),

        # Numeric → Scaling
        ('num', StandardScaler(), num)
    ]
)
preprocessor
# Out:
# ColumnTransformer(transformers=[('cat', OneHotEncoder(drop='first'),
#                                  ['Gender']),
#                                 ('num', StandardScaler(),
#                                  ['Age', 'EstimatedSalary'])])

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# Make a model 
model = Pipeline(steps=[
    ("preprocessing ", preprocessor),
    ("Classification " , LogisticRegression())
])
model
# Out:
# Pipeline(steps=[('preprocessing ',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['Gender']),
#                                                  ('num', StandardScaler(),
#                                                   ['Age',
#                                                    'EstimatedSalary'])])),
#                 ('Classification ', LogisticRegression())])

# %%
# Split into Training and Testing
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=.2,random_state=40)

# %%
# Fit model into train data 
model.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('preprocessing ',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['Gender']),
#                                                  ('num', StandardScaler(),
#                                                   ['Age',
#                                                    'EstimatedSalary'])])),
#                 ('Classification ', LogisticRegression())])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

y_pred = model.predict(X_test)

# Check Accuracy based on test data
acc = accuracy_score(y_pred,y_test)
con = confusion_matrix(y_pred,y_test)

print("Accuracy of model :",acc)
print("Confusion metrix :",con)
# Out:
# Accuracy of model : 0.8375
# Confusion metrix : [[54 11]
#  [ 2 13]]

# %%
# Check by Live input

live = pd.DataFrame({
    'Gender' :["Male"], 
    'Age' : [35], 
    'EstimatedSalary' : [57000],
    
})

prob = model.predict_proba(live)
positive_prob= prob[0][1]
label = 'Purchased' if positive_prob > 0.50 else "not"

print("prediction :",label)
print("positive Porbability :",positive_prob)
# Out:
# prediction : Purchased
# positive Porbability : (array([0.88632515, 0.11367485]), [1])
